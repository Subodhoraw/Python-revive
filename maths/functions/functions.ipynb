# %% [markdown]
# ### function
# liner function.
# f(x) = 1x + 0

# %%
import math
def linear_function(x,a,b):
   return a*x +b 

#example usage 
results = linear_function(2,1,0)
print(f"f(x) = {results}")
# Out:
# f(x) = 2
